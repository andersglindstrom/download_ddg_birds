# %%
# !pip install -Uqq fastbook

# %%
# !pip install -Uqq duckduckgo-images-api

# %%
from fastbook import search_images_ddg

# %%
results = search_images_ddg("bird photos")

# %%
results
# Out:
# (#200) ['https://images.pexels.com/photos/1406506/pexels-photo-1406506.jpeg?auto=compress&cs=tinysrgb&dpr=1&w=500','https://1.bp.blogspot.com/-xG7KlDtFEnY/ULNsZz12FEI/AAAAAAAAAHI/FV9XMOh4y0E/s1600/Canary-Bird-Picture.jpg','https://lh3.googleusercontent.com/-RKcFEkjqSKo/TYPYioAxssI/AAAAAAAAF_Q/fytXMe_0Zt8/s1600/12827108916B7BZFj.jpg','https://c.pxhere.com/photos/17/4d/bird_robin_nature_foraging_close_animals_birds_songbirds-1370230.jpg!d','http://2.bp.blogspot.com/-g9STQqFQ9Ik/UScse2IifqI/AAAAAAAAA08/mh1immEtVZo/s1600/bluebird.jpg','https://www.wallpapers13.com/wp-content/uploads/2016/07/Bird-Desktop-Wallpaper-Beautiful-Cardinal-Bird-1600x1200.jpg','https://wallpapercave.com/wp/2Xcu5EJ.jpg','https://lh3.googleusercontent.com/-uB8Ph5QEeDk/TYPYYBGPcYI/AAAAAAAAF90/sHzUKNhn-QQ/s1600/1261600366sQW1yRv.jpg','https://wallup.net/wp-content/uploads/2019/09/137093-birds-parrot.jpg','https://cdn.pixabay.com/photo/2013/11/25/17/28/bird-218216_960_720.jpg'...]

# %%
len(results)
# Out:
# 200

# %%
from fastdownload import download_url
dest = 'bird.jpg'
download_url(results[0], dest, show_progress=False)

from fastai.vision.all import *
im = Image.open(dest)
im.to_thumb(256,256)
# Out:
# <PIL.Image.Image image mode=RGB size=256x208>
